# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# first we import the pandas , numpy , matplotlib.pyplot and seaborn libraries and also warning library too
# there we giving alias name too

# %%
iris_data=pd.read_csv("IRIS.csv")

iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# here we read the csv file and store in the iris_data(data frame) and getting the counts of the rows and coulmn

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Getting the information from the data frame like datatypes and non-null count and what are the columns in the data frame and count of the datatypes

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Describe the columns what are present in the data frame and shows the count , mean , standard deviation , minimum value, maximum value, 25% 50% and 75% percentiles for the data which has present in the each columns.

# %%
iris_data[iris_data.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %% [markdown]
# retriving the duplicate datas from the dataframe

# %%
iris_data["sepal_length"].mean()
# Out:
# 5.843333333333334

# %%
iris_data["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris_data["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# When species are listed in this column, value-counts are used to count them. The data is then displayed as the number of species.

# %%
plt.title("Species Count")
sns.countplot(x=iris_data["species"])
# Out:
# <Axes: title={'center': 'Species Count'}, xlabel='species', ylabel='count'>

# %% [markdown]
# Use the matplotlib package to visualize the data, then enter "species count" as the title, "species" as the x-axis label, and "count" as the y-axis label. The species are iris-setosa, iris-versicolor, and iris-virginica. The number of each species in the dataset is displayed.

# %%
plt.figure(figsize=(10,5))
plt.title("compare species based on sepal length and width")
sns.scatterplot(x=iris_data["sepal_length"], y=iris_data["sepal_width"] , hue=iris_data["species"],s=50)
# Out:
# <Axes: title={'center': 'compare species based on sepal length and width'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# 1. First, set the headline to "compare species based on sepal length and width" and adjust the figure size.
# 2. import the Seborn library, comparing species according to sepal breadth and length using a scatter plot.
# 3. According to the scatter plot, the species Iris-setosa is primarily found in the lower left corner, with sepal lengths of 4-5 and sepal widths of 3-4.5 . Iris-versicolor is primarily seen in the lower middle, with sepal lengths of 5–6 and sepal widths of 2-3.5 . Iris-virginica is primarily found in the lower right corner, with sepal lengths of 5.5 to 8 and sepal widths of 2.5 to 3.5 .
# 4. To color the scatter plot according to the species, we use the hue parameter. The variation is readily apparent.
# 5. increasing the size of the markers in the scatter plot by setting the s variable to 50. This facilitates reading the plot.

# %% [markdown]
# notes:
#
#     1. sepal width is larger (3-3.5) and sepal length is (5.0 t0 5.5) small for iris-setosa
#     2. sepal width is smaller (2.5 to 3) and sepal length is distributed frm (5.5 to 6.5) for iris-verisicolor
#     3. sepal width is smaller sepal length is larger and distributed from(5.7 to 7.7)

# %%
plt.figure(figsize=(10,5))
plt.title("compare species based on petal length and width")
sns.scatterplot(x=iris_data["petal_length"], y=iris_data["petal_width"] , hue=iris_data["species"],s=50)
# Out:
# <Axes: title={'center': 'compare species based on petal length and width'}, xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# 1. First, set the headline to "compare species based on sepal length and width" and adjust the figure size.
# 2. Comparing species according to petal length and width using a scatter plot
# 3. By looking at the scatter plot, we can observe that the species iris-versicolor is primarily found in the upper right corner of the plot, whereas the species iris-setosa is primarily found in the lower left corner. This suggests that iris-setosa typically has smaller petals in terms of both length and width than iris-versicolor.
# 4. The petals in iris-setosa have a width of 0 to 0.5 and a length of 0 to 1.5, while the petals in iris-versicolor have a width of 1 to 1.5 and a length of 3 to 5.Iris virginica has petals that are 1.5 to 2.5 in width and 3.5 to 7 in length.
# 5. We color the scatter plot according to the species using the hue parameter. Variation is readily visible, and the scatter plot's markers are made larger by setting the s variable to 50. This facilitates reading the plot.

# %% [markdown]
# 1. iris-setosa is very small in petal length and petal width.
# 2. iris-versicolor is quite medium in size of petal lenth and petal width.--> they are neigther smaller nor larger
# 3. iris-virginica, the petal length is larger annd petal width is also larger

# %%
sns.pairplot(iris_data,hue="species" , height=4)

# %% [markdown]
# 1. Use the pairplot function to visualize the data after loading the dataset and importing the Seborn library.
# 2. to obtain data about each species in order to compare everything with one another.
# 3. The most common petal length of the species, in this case iris-setosa, is between 5 and 6. This is obtained by first counting the total number of petal lengths of the three species. and are 4-5 for iris-versicolor and 5-6 for iris-virginica.
# 4. The species Iris-setosa is primarily found in the lower left corner from sepal_width of 3-4.5 and sepal_length of 4-5.5, according to the next sepal_width vs. sepal_length graph for all three species. Iris versicolor is primarily found in the lower middle, with sepal lengths ranging from 5 to 6.5 and sepal widths from 2 to 3.5. Iris-virginica is primarily found in the lower right corner, with sepal lengths of 5.5 to 8 and sepal widths of 2.5 to 3.5.
# 5. After calculating the total number of sepal widths for the three species, the most common sepal widths for iris-setosa are found to be between 3 and 4. and are 2-3 for iris-versicolor and 2.5-3.5 for iris-virginica.
# 6. Compare the lengths of the petals and sepals for each of the three species. We can observe that Iris-setosa is primarily found in the lower left corner, with petal lengths of 1-2 and sepal lengths of 4-5.5. Iris-versicolor is primarily found in the lower middle, with petal lengths ranging from 4-5 and sepal lengths ranging from 5-6.5. From sepal_length of 5.5-8 to petal_length of 5-6, the species Iris-virginica is primarily found in the lower right corner.
# 7. Sepal breadth versus petal length The species Iris-setosa is primarily found in the lower left corner of all three species, with petal lengths of 1-2 and sepal widths of 3-4. Iris-versicolor is primarily found in the lower middle, with sepal widths of 2-3 and petal lengths of 4-5. Iris-virginica is primarily found in the lower right corner, with sepal widths of 2.5–3.5 and petal lengths of 5–6.
# 8. The petal lengths of the three species are now counted, and the most common petal lengths for iris-setosa are found to be between 1-2. and are 4-5 for iris-versicolor and 5-6 cm for iris-virginica.
# 9. Iris-setosa is primarily found in the lower left corner from petal_width of 0.1-0.3 and sepal_length of 4-5.5, while Iris-versicolor is primarily found in the bottom middle from petal_width of 0.4-0.6 and sepal_length of 5-6.5. By comparing the petal_width and sepal_length of the three species, we can observe that Iris-virginica is primarily found in the lower right corner from petal_width of 0.6-0.8 and sepal_length of 5.5-8.
# 10. By comparing the three species' petal and sepal widths, we can observe that Iris-setosa is primarily found in the lower left corner, with petal widths ranging from 0.1 to 0.5 and sepal widths ranging from 3 to 4. Iris-versicolor is primarily found in the lower middle, with sepal widths of 2-3 and petal widths of 0.4-0.6. Iris-virginica is primarily found in the lower right corner, with sepal widths of 2.5–3.5 and petal widths of 0.6–0.8.
# 11. Examine the three species' petal_length and petal_width. In iris-setosa, the petal length ranges from 0 to 1.5 while the petal width ranges from 0 to 0.5. The petal_width and petal_length in iris-versicolor are 1 to 1.5 and 3 to 5, respectively.Iris virginica has petals that are 1.5 to 2.5 wide and 3.5 to 7 long.
# 12. After calculating the total number of petals in all three species, the most common petals in each species are found to be between 0.1 and 0.5  for iris-setosa, 0.4 and 0.6 for iris-versicolor, and 0.6 and 0.8 for iris-virginica.

# %% [markdown]
# ### Univariate Analysis
#
#
# 1. sepal length
#     - Iris-setosa - sepal length  is quite high about 8.0 while comparing other species
#         and most of setosa falls in the range of 4.5 to 5.5 in sepal length.
#     - Iris-Versicolor and Iris-virginica are slightly less sepal Lengths about 6.0 and most of them are in the range of 5.5 to 6.5 in sepal length
#     - And most of the Viriginica fall in the range of  6 to 7.5 of sepal length
# 2.  sepal width is distributed higher for versicolor and virginica , but setosa has smaller sepal width
#     - most of them in versicolor are distributed in the lower range about 2 to 2.5 .
#     - Most of the Virginica are in the range of 2.5 to 3 in sepal width
#     - setosa are in the range 3 to 4
# 3. petal length
#     - most of the setosa fell in the range of 2 in petal length.
#     - most versicolor - 2.5 to 5.5 of petal length
#
#     - most virginica-4.5. to 7.5 of petal length

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# getting the columns name from the dataframe

# %% [markdown]
# Conclusion:
# 1. Based on the information presented, we must draw conclusions about the three species,
# 2. Iris setosa - The highest sepal length is almost five, and most iris setosa sepal lengths fall between 4 and 5.5. The sepal breadth is between 3 and 4. The petal length of the iris setosa is shorter than that of the other two species, ranging from 1 to 1.5, and the majority of them fall within this range only in under 2. The petal widths of the iris setosa lie mostly between 0.2 and 0.4.
# 3. Iris Versicolor - Most of them are in the range of 5.5 to 6.5 in iris-versicolor, with a somewhat smaller sepal length of 6. The majority of them are distributed in 2.5 to 3 sepal widths in iris versicolor. The majority of the iris versicolor in petals 3.5 to 5. The width of the petals ranges from one to two.
# 4. Iris-virginica - The petal lengths of Iris virginica typically range from 6 to 7.5. The majority of them fall between 2.5 and 3 in sepal breadth on the iris virginica. The majority of iris virginica have petals that range in length from 5 to 6.5. Iris virginica petals range in width from 1.5 to 2.5
